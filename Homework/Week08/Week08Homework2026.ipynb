# %% [markdown]
# # Week 8 Data preproccessing
#
# # Question 1
# - Import the pandas library with pd as a shortcut.
# - Read in the Ames housing data from a file named "AmesHousing.csv". Store it in a variable called ames.
# - Display the first 5 records of the data.
# - In a new code cell, use the info method to display the columns.

# %% [markdown]
# # Question 2 - Drop columns with no information
# Drop the first three columns because they represent columns with unique record numbers.
# - Create a list LD with "Unnamed: 0", "Order", "PID" in the list.
# - drop the columns in LD using the inplace = True.
# - list the columns of ames after the drop.

# %% [markdown]
# # Question 3 - Drop the Street and Utilities Columns
# Drop columns that has 95% or more with one answer in the column.
# - Display the percentage of the 'Street' column
# - Drop the 'Street' column
# - Display the percentage of the 'Utilities' column
# - Drop the 'Utilities' column
# - Display the percentage of the 'Condition 2' column
# - Drop the 'Condition 2' column

# %% [markdown]
# ames.drop("Street", axis = 1, inplace = True)

# %% [markdown]
# # Question 4 - Determine the Outliers in the data set
# In the ames dataframe
# - Find the indexes of the ames data where the 'Lot Area' is greater than 100000 square foot store it in the variable outliers.
# - Drop the records associated with the indexes.

# %% [markdown]
# # Question 5 - Create a histogram of the Target Variable
# The target column is the one you want to predict.  In this case, the target column is 'SalePrice'.  The model used to predict a continuous variable is called a regression model.  The linear model assumes the data is normally distributed (bell shaped).  We can test the assumption by creating a histogram of the SalePrice.
# - Create a histogram that is 'm' (magenta), the edgecolor 'b' (blue), the title is 'Sales Price Distribution', and number of bins equal to 30.
# - Import the numpy library as shortcut np
# - Create a new column called log_salePrice by applying np.log to the 'SalePrice' column.
# - Create a histogram that is 'm' (magenta), the edgecolor 'b' (blue), the title is 'Log of Sales Price Distribution', and number of bins equal to 30.

# %% [markdown]
# # Question 6 - Change missing to None
# Some of the columns has missing values and the missing values should be replaced with none.  This is the case with the following columns.
# - Create a list with the following columns 'Alley', 'Fence', 'Garage Type' and store it in a variable call XN.
# - Create a for loop with index x to cycle through the list, XN changing missing value to 'None'.

# %% [markdown]
# # Question 7 - Change missing values to 0
# Some columns missing values should be replaced with 0.  Note: this does not apply to all columns with missing values.
# - Create a list with the column names 'Mas Vnr Area', 'BsmtFin SF 1', 'Total Bsmt SF', 'Bsmt Full Bath' and store in variable NB.
# - Create a for loop that cycles through NB and has index x.
# - Change the missing values to 0

# %% [markdown]
# # Question 8 - Mapping Ordinal Variables
# Sometimes your data that is labels has an order to them.  When that occurs you convert the labels into numbers.
# - Display the values in the 'Kitchen Qual' column with percentages for each value.
# - Create a quality dictionary with Ex (5), Gd (4), TA (3), Fa (2), Po (1) store it in a variable called qual_map.
# - Change the labels to numbers if any value is missing replace with 3.

# %% [markdown]
# # Question 9 - Feature Engineering
# Sometimes you can improve your model by combining existing columns.  This process is called Feature Engineering.  Your dataset name is ames.
# - Display the Paved Drive column with percentages
# - Create a dictionary called pave_map with 'Y' : 2, 'P' : 1, 'N' : 0 .
# - Map column 'Paved Drive' to pave_map.
# - Create a new column called 'Driveway_Garage_Quality' as the product of 'Paved Drive' and 'Garage Cars' ('Paved Drive' * 'Garage Cars').

# %% [markdown]
# # Question 10 - Split Data into Test and Training Datasets
# Once the data has been cleaned and new columns have been created, it is time to split the data into train and test data sets.
# - from sklearn.model_selection import the train and test split
# - Create bins from the SalePrice column and save a new column called price_cat.
# - Split the data into train and test data sets
# - Drop the new column, price_cat, from both the train and test data sets.
