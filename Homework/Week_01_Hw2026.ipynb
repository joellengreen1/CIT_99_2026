# %% [markdown]
# # Question 1 - Python Expressions
# ### In your homework work assignment start entering code in this Jupyter Notebook starting with question 4.

# %% [markdown]
# # Question 2 - Python Data Types
# ### Enter the type function for each of the homework question 5.  Run each cell.

# %% [markdown]
# # Question 3 - Python Assignment of variables
# ### Enter your code for Question 7 of the week's homework.

# %% [markdown]
# # Question 4 - Concatenating Strings
# ### Enter the code for Question 8 of the week's homework.

# %%
# Out:
# float

# %% [markdown]
# # Question 5 - Replication of Strings
# ### Enter the code for Question 9 of Week 1 homework

# %%
# Out:
# 'helphelphelphelphelp'

# %% [markdown]
# # Question 6 - Use the input and print functions
# ### Enter the code for Question 10 of Week 1 homework

# %% [markdown]
# # Question 7 - if-statement
# ### Enter your code for Question 11 of Week 1 Homework

# %% [markdown]
# # Finished
# - Save the Jupyter Notebook and
# - Download it.
# - Upload it to Week 1 Assignment.
