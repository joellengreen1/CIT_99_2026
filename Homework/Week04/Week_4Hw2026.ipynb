# %% [markdown]
# # Week 4 - Homework - Numpy library

# %% [markdown]
# # Question 1
# ### Given the List L1 = [34, 56, 23, 45, 78, 90, 102], convert it to a numpy array and assign it to the variable L2.  Display L2.  First, you will need to import numpy as np.

# %% [markdown]
# # Question 2
# ## Given an vector Array  with the following numbers 74, 85, 96, 41, 52, 63 and perform the following operations on the array.
#
# - Import the Numpy library
# - Use the number above to define the array K.
# - Define a new array M as the K + 3.
# - Display M.
# - In a new code cell, raise each element in array K to the 2nd power and store in variable H.
# - Display H.
# - In a new code cell, add the two array M and K and store in variable I.
# - Display I.
# - In a new code cell, perform 3 * K  - 5 * M store the result in J.
# - Display J.
# - In a new code cell, multiply K * 15 and divide by 3 store the result in G.
# - Display G.

# %% [markdown]
# # Question 3
# ### Given the matrix array below, determine it's size and shape.
#
# ### M = np.array([[1, 0, 2], [2, 9, 3], [3, 8, 4]])
#
# - import the numpy library
# - Define the array above assign it to variable M.
# - Find the size of the array assign it to variable N.
# - Display N
# - In in new code cell, find the shape of the array assign it to variable O.
# - Display O

# %% [markdown]
# # Question 4
# ### A vendor sells hot dogs and corn dogs at three different locations. His total sales ( in hundreds ) for January and Febrary from the three locations are given in the table below.
# ```
# S = np.array([[10, 8, 8, 7], [8, 6, 6, 7], [6, 4, 6, 5]])
# ```
# The first column are hot dog sales in January.  The second column are corn dog sales in January.  The third column are hot dog sales in February.  The fourth column are the corn dogs in February.  The first row is from location I.  The second row is from location II. The third row is from location III.
#
# - import numpy library
# - define the array S.
# - select the sales for location I and store it in the variable array L1.
# - Determine the total sales for Location I for January and February and store in sal_L1.  Use the sum and the item method to get sal_L1.
# - print out "Total Sales for Location I is " concatenated with the str of the total and a period.
# - select the sales for hot in January.  Store the total in L2.
# - Determine the total hot dog sales in January and store it in sales_L2.
# - print out "Total January hot dog sales is " concatenated with the str of the total and period.

# %% [markdown]
# # Question 5
# ### In this question you will generate a number of random numbers into an numpy array.
#
# - import the numpy library
# - generate one random number between 0 and 1.  Store it in variable x.
# - display the random number in variable x.
# - In a new code cell, generate 4 rows and 5 columns of random numbers between 0 and 1 and store in x1.
# - display the random numbers in variable x1.
# - In a new code cell, generate one random integer between 1 and 200.  Then store it in variable n.
# - display the variable n
# - In a new code cell, generate 4 rows and 5 columns of random integers between 1 and 200.  Then store the values in the variable n1.
# - display the variable n1.
# - In a new code cell, generate a random number from a normal distribution with mean = 66 and standard deviation = 2.5.  Store the value in variable m.
# - display m.
# - In a new code cell, generate 4 rows and 5 columns of random number from a normal distribution with mean = 66 and standard deviation = 2.5.  Store the values in the variable m1.

# %% [markdown]
# # Question 6 - Statistics of a vecctor array
# Given the following array<br><br>
# **H = np.array([74, 85, 96, 71, 82, 93, 41, 52, 63, 14, 25, 36, 17, 28, 39])**<br><br>
# compute the statistics (each in a new code cell).  Use item method to convert to scalar.
#  - import numpy library
#  - define H array
#  - compute the max
#  - In a new code cell, compute index of max value,
#  - In a new code cell, compute min,
#  - In a new code cell, compute index of min value,
#  - In a new code cell, compute mean,
#  - In a new code cell, compute median,
#  - In a new code cell, compute standard deviation,
#  - In a new code cell, compute variance,
#  - In a new code cell, compute sum of values in the array
#  - In a new code cell, compute 25th percentile
#  - In a new code cell, compute 75th percentile

# %% [markdown]
# # Question 7 - Matrix Array - Statistics
# X = array([[12, 13, 14, 15], [14, 15, 16, 17], [18, 19, 20, 21]])<br><br>
# Given the array above compute the statistics below using axis parameter.  For each statistics put code in new code cell.
#
# - import numpy library
# - define array X
# - mean of each row
# - mean of each column
# - sum of each row
# - sum of each column
# - standard deviation of each row
# - standard deviation of each column
# - variance of each row
# - variance of each column

# %% [markdown]
# # Question 8 Conditional Logic
#
# Given H = np.random.normal(45, 3.5, (4, 5)) code the following.  Put each calculation in a separate code cell.
#
# - import the numpy library
# - define the array H
# - compute the 25th percentile and store in q1
# - compute the 75th percentile and store in q3
# - compute the Interquartile range = q3 - q1 and store in variable iqr.
# - compute lower range q1 - 1.5 * iqr and store in ll.
# - compute upper range q3 + 1.5 * iqr and store in ul.
# - Use where statement to find the values less than ll.
# - Use where statement to find the values greater than ul.
