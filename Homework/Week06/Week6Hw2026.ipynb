# %% [markdown]
# # Week 6 Visualizing Data
# During this week, you will code some charts using matplotlib, pandas, and seaborn.  Use the code from the week 6 lecture video.  You will use the same dataset used in the Week 6 lecture.  You will need to import the matplotlib, pandas and seaborn libraries before we use the code to create the data visualization.

# %% [markdown]
# # Question 1 - Reading in the data set
#
# - import pandas library
# - read in the csv file heart.csv assign it to the variable score_df
# - Display using the head method the first 5 rows of the file.

# %% [markdown]
# # Question 2 - Finding unique values and counts
# ### Use the value_counts method for the score_df dataframe to find the unique values and counts for the following in a separate code cell.
# - exang
# - slope
# - restecg
# - thal

# %% [markdown]
# # Question 3 - Line Plots - Matplotlib library
# You will show the code to create a line plot for cholestrol(chol) from the heart_df dataframe.
# - import mathplotlib.pyplot with short cut plt.
# - assign the index from heart_df to the variable x.
# - assign the **chol** from heart_df to variable y.
# - create the fig, ax and subplots
# - use the ax plot for x and y
# - use the ax to set labels (x axis, y axis and title)
# - include a grid on the plot
# - show the graph using plt and show method

# %% [markdown]
# # Question 4  - Create a Histogram in Matplotlib
#
# - import the Matplotlib library with short cut plt
# - create the fig and ax subplots
# - create the histogram using hist method of ax.  Make the histogram cyan with blue edgecolor
# - set the labels to cholestrol and ylabel to frequency and the title to Histogram

# %% [markdown]
# # Question 5 - Create a scatterplot using Matplotlib with third variable
# - import the Matplotlib library with short cut plt
# - create the fig and ax for subplots
# - create ax.scatter using age as the x variable and cholestrol (chol) as the y variable and a third variable targe for color.  Use alpha = 0.3 and s = 200.
# - set the labels for x, y axis and title to x axis to age, y axis to chol, and title of Heart Disease

# %% [markdown]
# # Question 6 - Creating a Bar Charts
# Using pandas library to create a bar chart
# - import pandas with shortcut pd
# - Use the value_counts method for the "restecg" column in heart_df and assign it to hd
# - Assign "Resting electrocardiographic results" to x
# - Create a bar chart by using the plot method of a pandas dataframe.  Assign "bar to kind, x to xlabel, "Bar Chart" to title, "horizontal" to rot.

# %% [markdown]
# # Question 7 - Horizontal Bar Chart
# Using pandas library to create a bar chart
#
# - import pandas with shortcut pd
# - Use the value_counts method for the "restecg" column in heart_df and assign it to hd
# - Assign "Resting electrocardiographic results" to y
# - Create a bar chart by using the plot method of a pandas dataframe. Assign "barh" to kind, y to ylabel, "Bar Chart" to title, color as "green" and fontsize = 16.

# %% [markdown]
# # Question 8 - Use Pandas to create a Boxplots
#
# - import pandas as pd
# - assign the string "Cholestrol" to b1
# - assign the string "Maximum Heart Rate Achieved" to b2
# - Create a dictionary called blabels with "chol" associated with "Cholestrol" and "thalach" associated with "Maximum Heart Rate Achieved".
# - Assigned the columns from heart_df to hd and rename columns to dictionary values blabels by assigning columns to dictionary.
# - Assign "Cholestrol" and "Maximum Heart Rate Achieved" to list columnx.
# - apply plot method to hd and assign columnx to y, "box" to kind, "m" to color, "Box Plot to title.

# %% [markdown]
# # Question 9 - Linear Regression Plot using the Seaborn library
# Create a Linear Regression plot
# - import the seaborn library with shortcut so
# - Create a dictionary call blabel that "chol" associated with "Cholestrol"
# - Take heart_df and select age and chol.  Then rename "chol" using columns = blabel save new dataframe in hd
# - Use the hd dataframe regplot method with x = "age" and y = "Cholestrol".

# %% [markdown]
# # Question - Density Plot
# - import seaborn library with shortcut so
# - import matplotlib library with shortcut plt
# - create fig and ax usig subplots for plt
# - create title for ax set to "Females"
# - Select "Female" from heart_df["sex"] == 0 using heart_df.loc assign to hd variable
# - create a dictionary called blabel target associated with "Heart Disease"
# - rename target to "Heart Disease" in the hd dataframe and save to hd
# - use the shortcut so use the kdeplot where data is hd, x = "age" and hue = "Heart Disease", fill = True

# %% [markdown]
# # Question 11 - PairPlot
# - import seaborn as shortcut so
# - Use so and use the pairplot method to create a set of plots for all variables that are in heart_df with hue equal to "Heart Disease"
