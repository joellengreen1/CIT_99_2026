# %% [markdown]
# # Week 7 - Data Preprocessing
#
# ## Cleaning Data
# You will be cleaning the Boston housing data.  It is a real dataset; however, I have randomly remove values in this data set so you can address messy data.  The first step in the cleaning process is to read in the dataset.<br>
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per 10,000 dollars
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's
#
#
# Please change the variables as indicated in the question.
#
#
# # Question #1
# 1. Import the pandas library.
# 2. Read the boston_clean.csv into a pandas dataframe  and store it in the variable **boston**.
# 3. View the first 10 records of boston using head method.

# %% [markdown]
# # What are the columns in your Dataframe
# You need to know how many records are in your dataframe and the data types for each feature variable.
#
# # Question 2
# 1. Use the info() method of the boston dataframe to find a list of columns and the data types of each feature.

# %% [markdown]
# # Delete Columns that are of no information
#
# The Unnamed feature is of no value since it is like record number.
#
# # Question 3
# 1. Use the drop() method to remove the dataframe.
# 2. Use the info() method to confirm that you dropped the Unnamed column from the boston dataframe.

# %% [markdown]
# # Duplicate Records
#
# It is a good idea to know how many duplicate records there are. Especially since we have such a small dataset.
#
# # Question 4
# 1. Determine duplicate records and keep the first duplicate record.  Then store it in b_dup.
# 2. Use an if b_dup.size is not equal to 0 and drop the duplicate records in boston dataframe using the inplace parameter.

# %% [markdown]
# # Column Data Types
#
# Given the modified Boston Housing Dataset, examine the definitions of each column.
#
# The following describes the dataset columns:
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable ('River' if tract bounds river; 'Other' otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per Ten Thousand dollars
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - percentage lower status of the population
# - MEDV - Median value of owner-occupied homes in thousands of dollars
#
# # Fix the TAX column
#
# # Question 5
#
# 1. In the first code cell, list the unique values of the TAX column and identify the error in the column.
# 2. In the second code cell, list the records with the error.
# 3. In the third code cell, change the value to a correct string using the loc.
# 4. In the third code cell, change the column to a float.
# 5. In the third code cell, use the info() method to list the columns

# %% [markdown]
# # Number of missing values
#
# # Question 6
# 1. Determine the number of missing values in each column using the isna().sum() method for the boston data set.

# %% [markdown]
# # Question #5
# - In the first code cell, determine the unique values in CHAS column using the unique() method.

# %% [markdown]
# # Describe the Numerical data
#
# To see a statistical description of the data, you can determine if there are outliers in your data set.  Look at the minimum values in each column, and if there are negative values where it is not possible, those records will be dropped.
#
# # Question #8
#
# - Run the describe().T method for the boston dataframe.
# - Identify the negative records and determine their indices for the first column that has a negative minimum value.  Store the indices in a variable called b_index_1.
# - Drop the b_index_1 records using the inplace parameter from the boston dataframe.
# - Identify the second column with a negative minimum value that should not be negative.
# - Identify the negative records and determine their indices.  Store the indices in a variable called b_index_2.
# - Drop the b_index_2 records using the inplace parameter from the boston dataframe.

# %% [markdown]
# # Create histograms for all numeric data
#
# # Question 9
# 1. Create a list of all the numerical data columns.  Store in L1.  Use the order from the info() method.
# 2. Use a for loop with index x to create a histogram using pandas.plot for each column in List L1.  Parameters in this order: y, kind, color, edgecolor, and title.  The title should be "Histogram of ' + x.  The color should be purple, and the edgecolor should be black.  The figure size is 5 by 5.

# %% [markdown]
# # Save the data set to work on in the future
# Use the following code to save your dataset for the future.
#
#
# # Question 10
# 1.  Use the code above to save your dataset to be used next week and name it boston_eda.csv.
