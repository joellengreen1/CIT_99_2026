# %% [markdown]
# # Week 16 - Exploring your Dataset
# During this week, you will....
# - select a data set
# - explore it using info and head methods
# - determine if the data set imbalanced based on a categorical variable.
# - split the data set stratifying by a variable you want to make sure it has the same amount in the train and test datasets
# - check the train and test data set for the distribution of variable in each dataset.
# - create a histogram of a variable in the dataset
# - create a scatterplot of two numeric variables in the dataset
# - run and display the describe method on the data set
# - run and display the correlation on the train data set
# - save the train and test datasets for next weeks work.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer, load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import silhouette_score
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# # Q1  Selecting a dataset
# - Load your data.  Store your data in a pandas dataframe named data_df.

# %% [markdown]
# # Q2 Display Data
# - Display the structure of your dataset, data_df using the info method.
# - In another code cell, display the first five records in your dataset, data_df using the head method.

# %% [markdown]
# # Q3 Check for duplicate Records
# 1. Determine duplicate records in data_df and keep the first duplicate record.  Then store it in d_dup.
# 2. Use an if d_dup.size is not equal to 0
# 3. drop the duplicate records in data_df dataframe using the keep = first, ignore_index = True, inplace parameter.
# 4. Run the info method on the data_df dataframe

# %% [markdown]
# # Time for you to shine
# - In the code cells below, add new columns
# - If the missing values are not np.nan change them to np.nan
# - Any other thing you wish to do to your dataset before splitting it into train and test datasets do here.  Add code cell if necessary.

# %% [markdown]
# # Q4 Categorical Variable
# - Assign a categorical variable to the variable column name strafcol.  Choose a variable that you think should have the same percentage of records in train and test datasets.
# - Determine the distribution of that column strafcol using the value_counts(normalize = True) * 100

# %% [markdown]
# # Q5 Split the data set into Train and Test
# - split the dataset into train and test datasets using a 70% train and 30% test stratify by the categorical column strafcol.

# %% [markdown]
# # Q6 Check distribution of the train and test dataset
# - check the distribution of the strafcol for the train dataset using the value_counts(normalize = True) * 100
# - check the distribution of the strafcol for the test dataset using the value_counts(normalize = True) * 100

# %% [markdown]
# # Q7 Statistical Summary
# - Run the describe().T method on the train dataframe for numeric summary
# - Run the describe(include = '[object]') for categorical values.

# %% [markdown]
# # Q8 Histogram
# - Assign a variable you want to create a histogram for to the variable histcol.
# - Create histogram plot using train.plot y = "histcol", kind = "hist",
# -        color = "navy", edgecolor = "yellow",
# -        title = "Histogram", figsize = (6, 6)

# %% [markdown]
# # Q9 Scatterplot
# - Assign a numeric column to LX. LX = 'x column'
# - Assign a numeric column to LY. LY = 'y column'
# - Assign a string title to LT. LT = "x column vs y column'
# - using the train.plot.scatter method to create a scatterplot use the following parameters: x = Lx, y = Ly, c = 'navy', title = LT);

# %% [markdown]
# # Q10 Correlation Matrix
# - Create a list of numeric columns and store in num_cols
# - Create a correlation matrix of the columns in the num_cols list and store it in the cor_matrix.
# - Display the cor_matrix.

# %% [markdown]
# # Q11 Save the train and test datasets
# - save the train dataframe to a csv file using dataframe method to_csv(index = False)
# - save the test dataframe to a csv file using dataframe method to_csv(index = False)
